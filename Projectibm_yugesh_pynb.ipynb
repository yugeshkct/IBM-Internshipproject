# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/sales_data_sample.csv",encoding='Windows-1252')
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2818  12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819  1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821  3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE  COUNTRY  \
# ...

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
df['ORDERNUMBER'].unique()
# Out:
# array([10107, 10121, 10134, 10145, 10159, 10168, 10180, 10188, 10201,
#        10211, 10223, 10237, 10251, 10263, 10275, 10285, 10299, 10309,
#        10318, 10329, 10341, 10361, 10375, 10388, 10403, 10417, 10103,
#        10112, 10126, 10140, 10150, 10163, 10174, 10183, 10194, 10206,
#        10215, 10228, 10245, 10258, 10270, 10280, 10291, 10304, 10312,
#        10322, 10333, 10347, 10357, 10369, 10381, 10391, 10411, 10424,
#        10120, 10210, 10236, 10298, 10308, 10339, 10374, 10402, 10362,
#        10105, 10119, 10129, 10143, 10155, 10167, 10178, 10186, 10197,
#        10209, 10222, 10248, 10261, 10273, 10283, 10295, 10307, 10316,
#        10325, 10337, 10350, 10359, 10373, 10384, 10395, 10400, 10414,
#        10114, 10164, 10175, 10207, 10217, 10229, 10259, 10281, 10305,
#        10313, 10334, 10370, 10425, 10108, 10122, 10135, 10147, 10169,
#        10181, 10191, 10203, 10225, 10238, 10253, 10266, 10276, 10287,
# ...

# %%
df['ORDERNUMBER'].value_counts()
# Out:
# 10332    18
# 10106    18
# 10159    18
# 10168    18
# 10398    18
#          ..
# 10242     1
# 10189     1
# 10286     1
# 10216     1
# 10294     1
# Name: ORDERNUMBER, Length: 307, dtype: int64

# %%
df['QUANTITYORDERED'].value_counts()
# Out:
# 34    112
# 21    103
# 46    101
# 27    100
# 31     97
# 41     97
# 45     97
# 26     96
# 29     94
# 48     94
# 25     94
# 20     93
# 33     92
# 22     92
# 32     91
# 24     91
# 38     91
# 49     91
# 36     89
# 44     89
# 37     87
# 43     85
# 39     84
# 28     82
# 40     78
# 42     76
# 30     75
# 23     73
# 35     71
# 47     70
# 50     65
# 55     16
# 66      5
# 15      4
# 51      4
# 61      3
# 18      3
# 60      3
# 76      3
# 59      3
# 56      3
# 19      3
# 64      3
# 10      2
# 6       2
# 11      2
# 54      2
# 70      2
# 97      1
# 85      1
# 62      1
# 52      1
# 16      1
# 13      1
# 58      1
# 65      1
# 12      1
# 77      1
# Name: QUANTITYORDERED, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10          10223               37     100.00                1  3965.66
# 21          10361               20      72.55               13  1451.00
# 40          10270               21     100.00                9  4905.39
# 47          10347               30     100.00                1  3944.70
# 51          10391               24     100.00                4  2416.56
# ...           ...              ...        ...              ...      ...
# 2667        10120               43      76.00               14  3268.00
# 2673        10223               26      67.20               15  1747.20
# 2685        10361               44     100.00               10  5001.92
# 2764        10361               35     100.00               11  4277.35
# 2791        10361               23      95.20               12  2189.60
#
#             ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.groupby('ORDERNUMBER')['PRICEEACH'].sum()
# Out:
# ORDERNUMBER
# 10120    1274.69
# 10125     200.00
# 10139     704.39
# 10148    1245.58
# 10169    1042.27
# 10223    1275.29
# 10270     988.51
# 10342     890.99
# 10347    1073.51
# 10361    1114.63
# 10370     776.87
# 10391     778.95
# 10420    1002.70
# Name: PRICEEACH, dtype: float64

# %%
df.groupby("QUANTITYORDERED")["PRICEEACH"].sum().plot.line()
# Out:
# <Axes: xlabel='QUANTITYORDERED'>

# %%
df.groupby("QUANTITYORDERED")["SALES"].sum().plot.line()
# Out:
# <Axes: xlabel='QUANTITYORDERED'>

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=df['QUANTITYORDERED'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Least Quantity odered 15

# %%
df.groupby('ORDERLINENUMBER')['SALES','PRICEEACH'].agg(['sum']).plot.bar()
plt.title("Total Profit and Sales per Orderlinenumber")
plt.show()
# Out:
# <ipython-input-26-bf893bb278a7>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('ORDERLINENUMBER')['SALES','PRICEEACH'].agg(['sum']).plot.bar()

# %% [markdown]
# Sales of oderlinenumber 2 is highest

# %%
sns.countplot(x=df['STATUS'])
# Out:
# <Axes: xlabel='STATUS', ylabel='count'>

# %%
sns.countplot(x=df['DEALSIZE'])
# Out:
# <Axes: xlabel='DEALSIZE', ylabel='count'>

# %% [markdown]
# Medium and Small dealsize are equal in count

# %%
df['SALES'].hist(bins=50,figsize=(15,8))
# Out:
# <Axes: >

# %% [markdown]
# From the above barchart Sales are higher in 2000 to 4000

# %%
df['SALES'].plot(kind="box",subplots=True,layout=(3,2),sharex=False,sharey=False)
plt.rcParams['figure.figsize']=[20,12]
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=df['STATE'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# NSW State has more number of oders
